# %%
import pandas as pd
import numpy as np

# %%
df_1 = pd.read_csv("data/tbl_player_power.csv")

# %%
df_1.head()
# Out:
#    int_power_id  int_player_id  int_shot_power  int_jumping  int_stamina  \
# 0             1              1              86           68           72
# 1             2              2              94           95           84
# 2             3              3              59           78           41
# 3             4              4              91           63           89
# 4             5              5              80           62           81
#
#    int_strength  int_long_shots
# 0            69              94
# 1            78              93
# 2            78              12
# 3            74              91
# 4            50              84

# %%
df_2 = pd.read_csv("data/tbl_player_profile.csv")

# %%
df_2.head()
# Out:
#    int_profile_id  int_player_id str_preferred_foot  int_weak_foot  \
# 0               1              1               Left              4
# 1               2              2              Right              4
# 2               3              3              Right              3
# 3               4              4              Right              5
# 4               5              5              Right              5
#
#    int_skill_moves  int_international_reputations   str_work_rate  \
# 0                4                              5     Medium/ Low
# 1                5                              5       High/ Low
# 2                1                              3  Medium/ Medium
# 3                4                              4      High/ High
# 4                5                              5    High/ Medium
#
#   str_body_type
# 0        Unique
# 1        Unique
# 2        Unique
# 3        Unique
# 4        Unique

# %%
df_3 = pd.read_csv("data/teams.csv")

# %%
df_3.head()
# Out:
#    int_team_id      str_team_name                  str_league  int_overall  \
# 0            1          Liverpool  English Premier League (1)           85
# 1            2    Manchester City  English Premier League (1)           85
# 2            3        Real Madrid  Spain Primera Division (1)           85
# 3            4  FC Bayern München    German 1. Bundesliga (1)           84
# 4            5       FC Barcelona  Spain Primera Division (1)           84
#
#    int_attack  int_midfield  int_defence  int_international_prestige  \
# 0          86            84           86                          10
# 1          86            86           83                           9
# 2          84            87           84                          10
# 3          91            84           83                          10
# 4          82            87           83                          10
#
#    int_domestic_prestige  int_transfer_budget          str_defensive_style  \
# ...

# %%
df_4 = pd.read_csv("data/players.csv")

# %%
df_4.head()
# Out:
#    int_player_id                      str_player_name str_positions  \
# 0              1       Lionel Andrés Messi Cuccittini    RW, ST, CF
# 1              2  Cristiano Ronaldo dos Santos Aveiro        ST, LW
# 2              3                            Jan Oblak            GK
# 3              4                      Kevin De Bruyne       CAM, CM
# 4              5        Neymar da Silva Santos Júnior       LW, CAM
#
#   dt_date_of_birth  int_height  int_weight  int_overall_rating  \
# 0       1987-06-24         170          72                  93
# 1       1985-02-05         187          83                  92
# 2       1993-01-07         188          87                  91
# 3       1991-06-28         181          70                  91
# 4       1992-02-05         175          68                  91
#
#    int_potential_rating str_best_position  int_best_overall_rating  ...  \
# 0                    93                RW                       93  ...
# ...
